# %% [markdown]
# <a href="https://colab.research.google.com/github/alm36918/ciencia-de-dados/blob/master/nuvem_de_tags_nklt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Criação de Nuvem de Tags com Python.
#
# Faz parte do meu estudo sobre Ciência de Dados e Python.
#
# As Nuvens de Tags podem ser bem interessantes para avliação de textos médios ou longos sem, necessariamente, precisar ler. Pode ser utilizado para se ter uma ideia geral de um discurso, artigo ou notícia, por exemplo.

# %% [markdown]
# # Stopwords em Português

# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
print(stopwords.words('portuguese'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um', 'para', 'com', 'não', 'uma', 'os', 'no', 'se', 'na', 'por', 'mais', 'as', 'dos', 'como', 'mas', 'ao', 'ele', 'das', 'à', 'seu', 'sua', 'ou', 'quando', 'muito', 'nos', 'já', 'eu', 'também', 'só', 'pelo', 'pela', 'até', 'isso', 'ela', 'entre', 'depois', 'sem', 'mesmo', 'aos', 'seus', 'quem', 'nas', 'me', 'esse', 'eles', 'você', 'essa', 'num', 'nem', 'suas', 'meu', 'às', 'minha', 'numa', 'pelos', 'elas', 'qual', 'nós', 'lhe', 'deles', 'essas', 'esses', 'pelas', 'este', 'dele', 'tu', 'te', 'vocês', 'vos', 'lhes', 'meus', 'minhas', 'teu', 'tua', 'teus', 'tuas', 'nosso', 'nossa', 'nossos', 'nossas', 'dela', 'delas', 'esta', 'estes', 'estas', 'aquele', 'aquela', 'aqueles', 'aquelas', 'isto', 'aquilo', 'estou', 'está', 'estamos', 'estão', 'estive', 'esteve', 'estivemos', 'estiveram', 'estava', 'estávamos', 'estavam', 'estivera', 'estivéramos', 'esteja', 'estejamos', 'estejam', 'estivesse', 'estivéssemos', 'estivessem', 'estiver', 'estivermos', 'estiverem', 'hei', 'há', 'havemos', 'hão', 'houve', 'houvemos', 'houveram', 'houvera', 'houvéramos', 'haja', 'hajamos', 'hajam', 'houvesse', 'houvéssemos', 'houvessem', 'houver', 'houvermos', 'houverem', 'houverei', 'houverá', 'houveremos', 'houverão', 'houveria', 'houveríamos', 'houveriam', 'sou', 'somos', 'são', 'era', 'éramos', 'eram', 'fui', 'foi', 'fomos', 'foram', 'fora', 'fôramos', 'seja', 'sejamos', 'sejam', 'fosse', 'fôssemos', 'fossem', 'for', 'formos', 'forem', 'serei', 'será', 'seremos', 'serão', 'seria', 'seríamos', 'seriam', 'tenho', 'tem', 'temos', 'tém', 'tinha', 'tínhamos', 'tinham', 'tive', 'teve', 'tivemos', 'tiveram', 'tivera', 'tivéramos', 'tenha', 'tenhamos', 'tenham', 'tivesse', 'tivéssemos', 'tivessem', 'tiver', 'tivermos', 'tiverem', 'terei', 'terá', 'teremos', 'terão', 'teria', 'teríamos', 'teriam']

# %% [markdown]
# # Dividindo o texto em sentenças

# %%
from nltk.tokenize import word_tokenize 

import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Texto com e sem stopwords

# %%
texto = input("Texto para extrair a nuvem de tags: ")
  
stop_words = set(stopwords.words("portuguese"))

word_tokens = word_tokenize(texto)

texto_filtrado = [w for w in word_tokens if not w in stop_words]

texto_filtrado = []

for w in word_tokens:
    if w not in stop_words:
        texto_filtrado.append(w)

print("Essas são as palavras sem retirar as stopwords:", word_tokens)
print()
print("Essas são as palavras depois de retirar as stopwords:", texto_filtrado)
# Out:
# Texto para extrair a nuvem de tags: Dark é uma série com temáticas de terror, suspense, drama e ficção científica. Parecem os ingredientes corretos para o sucesso, certo? Talvez. Mas para entender a série, não é tão simples assim, pois ela se baseia em ficção e mistério para entrelaçar o roteiro, que por sua vez é bastante fantasioso. Mas o mais legal disso tudo é que os criadores Baran bo Odar e Jantje Friese conseguiram de forma honrosa iniciar e fechar a história de forma que faça sentido ao seu desfecho, mesmo quem em alguns momentos a trama se apresente confusa, no final ela explica muitas coisas. Já de início, no primeiro episódio, uma frase de Albert Einstein define todo o rumo da série: “A distinção entre passado, presente e futuro é apenas uma ilusão teimosamente persistente.” Esta é a afirmativa que conecta todo o contexto de Dark aos eventos que nela ocorrem. Apesar de ser uma historia que acontece no futuro, 2019, ela possui uma linha temporal linear, mesmo com todas as viagens no tempo, tudo está conectado e é simultâneo. Mesmo quando os personagens regressam aos anos de 1986 e 1953. A princípio pode parecer confuso a mecânica por trás da narrativa, mas ao ler um pouco sobre a Teoria Geral da Relatividade e a Teoria Especial da Relatividade, ambas de Einstein, podemos ficar um pouco menos confusos sobre o assunto. Outro estudo que recomendo para entendermos a série é sobre a Mecânica Quântica.
# Essas são as palavras sem retirar as stopwords: ['Dark', 'é', 'uma', 'série', 'com', 'temáticas', 'de', 'terror', ',', 'suspense', ',', 'drama', 'e', 'ficção', 'científica', '.', 'Parecem', 'os', 'ingredientes', 'corretos', 'para', 'o', 'sucesso', ',', 'certo', '?', 'Talvez', '.', 'Mas', 'para', 'entender', 'a', 'série', ',', 'não', 'é', 'tão', 'simples', 'assim', ',', 'pois', 'ela', 'se', 'baseia', 'em', 'ficção', 'e', 'mistério', 'para', 'entrelaçar', 'o', 'roteiro', ',', 'que', 'por', 'sua', 'vez', 'é', 'bastante', 'fantasioso', '.', 'Mas', 'o', 'mais', 'legal', 'disso', 'tudo', 'é', 'que', 'os', 'criadores', 'Baran', 'bo', 'Odar', 'e', 'Jantje', 'Friese', 'conseguiram', 'de', 'forma', 'honrosa', 'iniciar', 'e', 'fechar', 'a', 'história', 'de', 'forma', 'que', 'faça', 'sentido', 'ao', 'seu', 'desfecho', ',', 'mesmo', 'quem', 'em', 'alguns', 'momentos', 'a', 'trama', 'se', 'apresente', 'confusa', ',', 'no', 'final', 'ela', 'explica', 'muitas', 'coisas', '.', 'Já', 'de', 'início', ',', 'no', 'primeiro', 'episódio', ',', 'uma', 'frase', 'de', 'Albert', 'Einstein', 'define', 'todo', 'o', 'rumo', 'da', 'série', ':', '“', 'A', 'distinção', 'entre', 'passado', ',', 'presente', 'e', 'futuro', 'é', 'apenas', 'uma', 'ilusão', 'teimosamente', 'persistente.', '”', 'Esta', 'é', 'a', 'afirmativa', 'que', 'conecta', 'todo', 'o', 'contexto', 'de', 'Dark', 'aos', 'eventos', 'que', 'nela', 'ocorrem', '.', 'Apesar', 'de', 'ser', 'uma', 'historia', 'que', 'acontece', 'no', 'futuro', ',', '2019', ',', 'ela', 'possui', 'uma', 'linha', 'temporal', 'linear', ',', 'mesmo', 'com', 'todas', 'as', 'viagens', 'no', 'tempo', ',', 'tudo', 'está', 'conectado', 'e', 'é', 'simultâneo', '.', 'Mesmo', 'quando', 'os', 'personagens', 'regressam', 'aos', 'anos', 'de', '1986', 'e', '1953', '.', 'A', 'princípio', 'pode', 'parecer', 'confuso', 'a', 'mecânica', 'por', 'trás', 'da', 'narrativa', ',', 'mas', 'ao', 'ler', 'um', 'pouco', 'sobre', 'a', 'Teoria', 'Geral', 'da', 'Relatividade', 'e', 'a', 'Teoria', 'Especial', 'da', 'Relatividade', ',', 'ambas', 'de', 'Einstein', ',', 'podemos', 'ficar', 'um', 'pouco', 'menos', 'confusos', 'sobre', 'o', 'assunto', '.', 'Outro', 'estudo', 'que', 'recomendo', 'para', 'entendermos', 'a', 'série', 'é', 'sobre', 'a', 'Mecânica', 'Quântica', '.']
#
# Essas são as palavras depois de retirar as stopwords: ['Dark', 'série', 'temáticas', 'terror', ',', 'suspense', ',', 'drama', 'ficção', 'científica', '.', 'Parecem', 'ingredientes', 'corretos', 'sucesso', ',', 'certo', '?', 'Talvez', '.', 'Mas', 'entender', 'série', ',', 'tão', 'simples', 'assim', ',', 'pois', 'baseia', 'ficção', 'mistério', 'entrelaçar', 'roteiro', ',', 'vez', 'bastante', 'fantasioso', '.', 'Mas', 'legal', 'disso', 'tudo', 'criadores', 'Baran', 'bo', 'Odar', 'Jantje', 'Friese', 'conseguiram', 'forma', 'honrosa', 'iniciar', 'fechar', 'história', 'forma', 'faça', 'sentido', 'desfecho', ',', 'alguns', 'momentos', 'trama', 'apresente', 'confusa', ',', 'final', 'explica', 'muitas', 'coisas', '.', 'Já', 'início', ',', 'primeiro', 'episódio', ',', 'frase', 'Albert', 'Einstein', 'define', 'todo', 'rumo', 'série', ':', '“', 'A', 'distinção', 'passado', ',', 'presente', 'futuro', 'apenas', 'ilusão', 'teimosamente', 'persistente.', '”', 'Esta', 'afirmativa', 'conecta', 'todo', 'contexto', 'Dark', 'eventos', 'nela', 'ocorrem', '.', 'Apesar', 'ser', 'historia', 'acontece', 'futuro', ',', '2019', ',', 'possui', 'linha', 'temporal', 'linear', ',', 'todas', 'viagens', 'tempo', ',', 'tudo', 'conectado', 'simultâneo', '.', 'Mesmo', 'personagens', 'regressam', 'anos', '1986', '1953', '.', 'A', 'princípio', 'pode', 'parecer', 'confuso', 'mecânica', 'trás', 'narrativa', ',', 'ler', 'pouco', 'sobre', 'Teoria', 'Geral', 'Relatividade', 'Teoria', 'Especial', 'Relatividade', ',', 'ambas', 'Einstein', ',', 'podemos', 'ficar', 'pouco', 'menos', 'confusos', 'sobre', 'assunto', '.', 'Outro', 'estudo', 'recomendo', 'entendermos', 'série', 'sobre', 'Mecânica', 'Quântica', '.']

# %% [markdown]
# # Texto completo dividido em sentenças e sem stopwords

# %%
texto_completo = ', '.join(texto_filtrado)
print(texto_completo)
# Out:
# Dark, série, temáticas, terror, ,, suspense, ,, drama, ficção, científica, ., Parecem, ingredientes, corretos, sucesso, ,, certo, ?, Talvez, ., Mas, entender, série, ,, tão, simples, assim, ,, pois, baseia, ficção, mistério, entrelaçar, roteiro, ,, vez, bastante, fantasioso, ., Mas, legal, disso, tudo, criadores, Baran, bo, Odar, Jantje, Friese, conseguiram, forma, honrosa, iniciar, fechar, história, forma, faça, sentido, desfecho, ,, alguns, momentos, trama, apresente, confusa, ,, final, explica, muitas, coisas, ., Já, início, ,, primeiro, episódio, ,, frase, Albert, Einstein, define, todo, rumo, série, :, “, A, distinção, passado, ,, presente, futuro, apenas, ilusão, teimosamente, persistente., ”, Esta, afirmativa, conecta, todo, contexto, Dark, eventos, nela, ocorrem, ., Apesar, ser, historia, acontece, futuro, ,, 2019, ,, possui, linha, temporal, linear, ,, todas, viagens, tempo, ,, tudo, conectado, simultâneo, ., Mesmo, personagens, regressam, anos, 1986, 1953, ., A, princípio, pode, parecer, confuso, mecânica, trás, narrativa, ,, ler, pouco, sobre, Teoria, Geral, Relatividade, Teoria, Especial, Relatividade, ,, ambas, Einstein, ,, podemos, ficar, pouco, menos, confusos, sobre, assunto, ., Outro, estudo, recomendo, entendermos, série, sobre, Mecânica, Quântica, .

# %% [markdown]
# # Criando e printando a nuvem de tags de acordo com os parâmetros

# %%
from matplotlib.colors import ListedColormap
from wordcloud import WordCloud

# %%
stops = stopwords.words("portuguese")
mapa_cores = ListedColormap(["orange", "green", "red", "magenta"])
nuvem = WordCloud(background_color = "white",  height=600, width=1200, colormap = mapa_cores, stopwords = stops, max_words = 50)

# %%
nuvem.generate(texto_completo)

# %%
from matplotlib import pyplot as plt
plt.figure( figsize=(10,5))
plt.imshow(nuvem)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
